# %% [markdown]
# **Python version:**  3.x

# %%
# set the path of the directories where your modules and files are
modules_path = 'C:\\Users\loren\Documents\Progetti\__repo__\_myModules'
files_path = 'C:\\Users\loren\Documents\Progetti\Scuola\AdvDataMining\_files'

# %% [markdown]
# #### Moduli

# %%
import os
import sys

if os.path.isdir(modules_path) and modules_path not in sys.path:
    sys.path.append(modules_path)

modulesList = os.listdir(modules_path)
print('Available Modules for the project:', modulesList,sep='\n', end='\n\n')

filesList = os.listdir(files_path)
print('Available Files for the project:', filesList,sep='\n')

# %matplotlib inline

import df_handle
import data_understanding
import data_preparation
import modeling
import model_evaluation
# Out:
# Available Modules for the project:
# ['data_preparation.py', 'data_understanding.py', 'df_handle.py', 'modeling.py', 'model_evaluation.py', '__pycache__']
#
# Available Files for the project:
# ['datatest.txt', 'datatest2.txt', 'datatraining.txt', 'training.csv']

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df, ts = df_handle.import_df(file_name='training.csv', search_in_folder=files_path,
                             date_col_name='date', ts_name='Temperature', time_freq='min')

# %%
df
# Out:
#                      Temperature  Humidity  Light         CO2  HumidityRatio  \
# date
# 2015-02-04 17:51:00        23.18   27.2720  426.0  721.250000       0.004793
# 2015-02-04 17:52:00        23.15   27.2675  429.5  714.000000       0.004783
# 2015-02-04 17:53:00        23.15   27.2450  426.0  713.500000       0.004779
# 2015-02-04 17:54:00        23.15   27.2000  426.0  708.250000       0.004772
# 2015-02-04 17:55:00        23.10   27.2000  426.0  704.500000       0.004757
# ...                          ...       ...    ...         ...            ...
# 2015-02-10 09:29:00        21.05   36.0975  433.0  787.250000       0.005579
# 2015-02-10 09:30:00        21.05   35.9950  433.0  789.500000       0.005563
# 2015-02-10 09:31:00        21.10   36.0950  433.0  798.500000       0.005596
# 2015-02-10 09:32:00        21.10   36.2600  433.0  820.333333       0.005621
# 2015-02-10 09:33:00        21.10   36.2000  447.0  821.000000       0.005612
#
# ...

# %%
ts
# Out:
# 2015-02-04 17:51:00    23.18
# 2015-02-04 17:52:00    23.15
# 2015-02-04 17:53:00    23.15
# 2015-02-04 17:54:00    23.15
# 2015-02-04 17:55:00    23.10
#                        ...
# 2015-02-10 09:29:00    21.05
# 2015-02-10 09:30:00    21.05
# 2015-02-10 09:31:00    21.10
# 2015-02-10 09:32:00    21.10
# 2015-02-10 09:33:00    21.10
# Freq: T, Name: Temperature, Length: 8143, dtype: float64

# %%
plt.plot(ts)
plt.show()

# %%
modeling.stationarity_test(ts=ts)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                   -2.694434
# p-value                           0.075006
# #Lags Used                       21.000000
# Number of Observations Used    8121.000000
# Critical Value (1%)              -3.431155
# Critical Value (5%)              -2.861896
# Critical Value (10%)             -2.566959
# dtype: float64

# %%
stationary_ts=data_preparation.stationarize_ts(ts, mov_avg_periods=300)

# %%
stationary_ts
# Out:
# 2015-02-04 22:50:00   -0.027645
# 2015-02-04 22:51:00   -0.027362
# 2015-02-04 22:52:00   -0.031305
# 2015-02-04 22:53:00   -0.026789
# 2015-02-04 22:54:00   -0.026510
#                          ...
# 2015-02-10 09:29:00    0.036972
# 2015-02-10 09:30:00    0.036835
# 2015-02-10 09:31:00    0.039062
# 2015-02-10 09:32:00    0.038900
# 2015-02-10 09:33:00    0.038747
# Freq: T, Name: Temperature, Length: 7844, dtype: float64

# %%
plt.plot(stationary_ts)
plt.show()

# %%
modeling.stationarity_test(ts=stationary_ts)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                   -3.877138
# p-value                           0.002210
# #Lags Used                       25.000000
# Number of Observations Used    7818.000000
# Critical Value (1%)              -3.431187
# Critical Value (5%)              -2.861910
# Critical Value (10%)             -2.566967
# dtype: float64

# %%
modeling.autocorr_func(stationary_ts)

# %% [markdown]
# # Forecast

# %%
ts_train, ts_test = df_handle.forecast_setup(stationary_ts, 6500)

# %% [markdown]
# ## \Simple Exponential Smoothing\

# %%
smoothing_level = 0

forecaster = modeling.SimpleExpSmoothing(ts_train).fit(smoothing_level=smoothing_level, optimized=True)
# Out:
# C:\Users\loren\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters.py:731: RuntimeWarning: invalid value encountered in greater_equal
#   loc = initial_p >= ub

# %%
model_evaluation.test_forecast(forecaster=forecaster, ts_test=ts_test, ts_train=ts_train, ts=stationary_ts)
# Out:
# MAE: 0.02018167943091304
# RMSE: 0.02633525328608261
# MAD: 0.014920170343623473
# R2: 0.003970767108334439
# MAPE: inf
# MAXAPE: inf
# TAPE: inf

# %%
smoothing_level=0.1
smoothing_slope=0.2

forecaster = modeling.Holt(ts_train).fit(smoothing_level=smoothing_level, smoothing_slope=smoothing_slope)
# Out:
# C:\Users\loren\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters.py:731: RuntimeWarning: invalid value encountered in greater_equal
#   loc = initial_p >= ub

# %%
model_evaluation.test_forecast(forecaster=forecaster, ts_test=ts_test, ts_train=ts_train, ts=stationary_ts)
# Out:
# MAE: 0.03071158765999601
# RMSE: 0.039344351675096714
# MAD: 0.02668752074568853
# R2: -1.223114709333717
# MAPE: 27.58423056773128
# MAXAPE: 31762.53176301051
# TAPE: 37073.20588303084

# %%
seasonal_periods=1000

forecaster = modeling.ExponentialSmoothing(ts_train, seasonal_periods=seasonal_periods, trend=None, seasonal='add').fit()
# Out:
# C:\Users\loren\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters.py:725: RuntimeWarning: invalid value encountered in less_equal
#   loc = initial_p <= lb
# C:\Users\loren\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters.py:731: RuntimeWarning: invalid value encountered in greater_equal
#   loc = initial_p >= ub

# %%
model_evaluation.test_forecast(forecaster=forecaster, ts_test=ts_test, ts_train=ts_train, ts=stationary_ts)
# Out:
# MAE: 0.07802876534437217
# RMSE: 0.08162951362145926
# MAD: 0.0773254754005871
# R2: -8.569549720568485
# MAPE: 1.0478116799262929
# MAXAPE: 2.2950686864038845
# TAPE: 1408.2588978209365

# %%
forecaster = modeling.ARIMA(ts_train, order=(3,0,1)).fit()

# %%
model_evaluation.test_forecast(forecaster=forecaster, ts_test=ts_test, ts_train=ts_train, ts=stationary_ts)
# Out:
# MAE: 0.01717796572067257
# RMSE: 0.022495094670655552
# MAD: 0.010148066418063467
# R2: 0.27327058988924036
# MAPE: 16.0598023235369
# MAXAPE: 7331.044275400741
# TAPE: 21584.37432283363

# %%
forecaster = modeling.SARIMAX(ts_train, order=(1,0,0), seasonal_order=(10, 1, 0, 1)).fit(disp=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-114-c03b00b83884> in <module>
# ----> 1 forecaster = modeling.SARIMAX(ts_train, order=(1,0,0), seasonal_order=(10, 1, 0, 1)).fit(disp=False)
#
# ~\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py in __init__(self, endog, exog, order, seasonal_order, trend, measurement_error, time_varying_regression, mle_regression, simple_differencing, enforce_stationarity, enforce_invertibility, hamilton_representation, concentrate_scale, trend_offset, use_exact_diffuse, dates, freq, missing, **kwargs)
#     330             trend=trend, enforce_stationarity=None, enforce_invertibility=None,
#     331             concentrate_scale=concentrate_scale, dates=dates, freq=freq,
# --> 332             missing=missing)
#     333         self._params = SARIMAXParams(self._spec)
#     334
#
# ...

# %%
model_evaluation.test_forecast(forecaster=forecaster, ts_test=ts_test, ts_train=ts_train, ts=stationary_ts)

# %%
pred_train = modeling.SARIMAX.predict(start=ts_train.index[0], end=ts_train.index[-1])

plt.plot(range(len(ts_train)), train, label='train')
plt.plot(range(len(ts_train)), pred_train, label='pred train')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-89-7229c75055aa> in <module>
# ----> 1 pred_train = modeling.SARIMAX.predict(start=ts_train.index[0], end=ts_train.index[-1])
#       2
#       3 plt.plot(range(len(ts_train)), train, label='train')
#       4 plt.plot(range(len(ts_train)), pred_train, label='pred train')
#       5 plt.legend()
#
# TypeError: predict() missing 2 required positional arguments: 'self' and 'params'
