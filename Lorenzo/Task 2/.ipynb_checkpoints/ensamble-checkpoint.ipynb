# %% [markdown]
# **Python version:**  3.x

# %% [markdown]
# ### Variabili da Inizializzare

# %%
# set the path of the directory where your modules are
modulesPath = 'C:\\Users\\loren\\Documents\\Progetti\\Scuola\\AdvDataMining\\__Repo__'

# %% [markdown]
# #### Moduli

# %%
import os
import sys

if os.path.isdir(modulesPath) and modulesPath not in sys.path:
    sys.path.append(modulesPath)

modulesList = os.listdir(modulesPath)
print('Available Files and Modules for the project:', modulesList,sep='\n')

# %matplotlib inline

import df_handle
import data_understanding
import data_preparation
import modeling
import model_evaluation
# Out:
# Available Files and Modules for the project:
# ['datatest.txt', 'datatest2.txt', 'datatraining.txt', 'data_preparation.py', 'data_understanding.py', 'df_handle.py', 'modeling.py', 'model_evaluation.py', '__pycache__']

# %%
X_train, X_test, y_train, y_test = df_handle.setup_df(trainFileName='datatraining.txt', y_name='Occupancy',
                                                      testFileName='datatest.txt', searchIn=modulesPath)
del X_train['date']
del X_test['date']

# %% [markdown]
# # \Random Forest\

# %%
clf = modeling.fit_best_clf(X_train=X_train, y_train=y_train,
                            model=modeling.RandomForestClassifier(criterion='gini',
                                                                  max_depth=None,
                                                                  min_weight_fraction_leaf=0.0,
                                                                  max_features='auto',
                                                                  random_state=0,
                                                                  n_estimators=50),
                            nbr_iter=10,
                            params_domain_dic={'min_samples_split': range(1,100),
                                               'min_samples_leaf': range(1,100)},
                            score_metric='f1')
# Out:
# Best values for searched parameters:
# {'min_samples_split': 97, 'min_samples_leaf': 57}

# %%
model_evaluation.test_clf(clf=clf,X_test=X_test,y_test=y_test)
# Out:
# Accuracy: 0.9786116322701689
#
# F1-score: [0.98290855 0.97142857]
#
# Weighted Average F1-score: 0.9787214781780913
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.98      1693
#            1       0.95      1.00      0.97       972
#
#     accuracy                           0.98      2665
#    macro avg       0.97      0.98      0.98      2665
# weighted avg       0.98      0.98      0.98      2665

# %%
model_evaluation.validate_clf(clf=clf, X_train=X_train, y_train=y_train)
# Out:
# Accuracy at a 95 percent confidence interval: 0.98 (+/- 0.04)
#
# Weighted Average F1 Score at a 95 percent confidence interval: 0.98 (+/- 0.03)

# %%
model_evaluation.feature_importance(estimator=clf, X_train=X_train, y_train=y_train)

# %%
model_evaluation.decision_boundary_scatterplots(clf=clf, X=X_train[['CO2', 'Light']], y=y_train, mesh_step=1)
